# %% [markdown]
# # Exemplary Usage of our Final Project
#
# ## 1 Correct inputs
#
# ### Margins

# %%
# %run main.py
# Out:
#         What aspect would you like to be visualized?
#         Choose one of the following options:
#         Type in:      Option:
# 	      mar 	 Winning / losing margins for all games in the season
# 	      pts 	 Average points per game in the season
# 	      orb 	 Average number of offensive rebounds in the season
# 	      drb 	 Average number of defensive rebounds in the season
# 	      acc 	 Shooting accuracy in the season
# 	      a/t 	 Average number of assists vs turnovers in the season
#
# Aspect: mar
#
#
#         From which season should the data be sourced?
#         Please type in the year in which the season ended.
#         For example, if you are interested in season 2021/22, type in:
#             2022
#
# Ending year of season: 2002
#
#
#         From which NBA team(s) should the data be sourced?
#         Please type in for each team either the three-letter abbreviation or
#         the official name. If you are interested in multiple teams,
# ...

# %%
# %run main.py
# Out:
#         What aspect would you like to be visualized?
#         Choose one of the following options:
#         Type in:      Option:
# 	      mar 	 Winning / losing margins for all games in the season
# 	      pts 	 Average points per game in the season
# 	      orb 	 Average number of offensive rebounds in the season
# 	      drb 	 Average number of defensive rebounds in the season
# 	      acc 	 Shooting accuracy in the season
# 	      a/t 	 Average number of assists vs turnovers in the season
#
# Aspect: mar
#
#
#         From which season should the data be sourced?
#         Please type in the year in which the season ended.
#         For example, if you are interested in season 2021/22, type in:
#             2022
#
# Ending year of season: 1947
#
#
#         From which NBA team(s) should the data be sourced?
#         Please type in for each team either the three-letter abbreviation or
#         the official name. If you are interested in multiple teams,
# ...

# %% [markdown]
# ### Points

# %%
# %run main.py
# Out:
#         What aspect would you like to be visualized?
#         Choose one of the following options:
#         Type in:      Option:
# 	      mar 	 Winning / losing margins for all games in the season
# 	      pts 	 Average points per game in the season
# 	      orb 	 Average number of offensive rebounds in the season
# 	      drb 	 Average number of defensive rebounds in the season
# 	      acc 	 Shooting accuracy in the season
# 	      a/t 	 Average number of assists vs turnovers in the season
#
# Aspect: pts
#
#
#         From which season should the data be sourced?
#         Please type in the year in which the season ended.
#         For example, if you are interested in season 2021/22, type in:
#             2022
#
# Ending year of season: 2014
#
#
#         From which NBA team(s) should the data be sourced?
#         Please type in for each team either the three-letter abbreviation or
#         the official name. If you are interested in multiple teams,
# ...

# %% [markdown]
# ### Offensive Rebounds

# %%
# %run main.py
# Out:
#         What aspect would you like to be visualized?
#         Choose one of the following options:
#         Type in:      Option:
# 	      mar 	 Winning / losing margins for all games in the season
# 	      pts 	 Average points per game in the season
# 	      orb 	 Average number of offensive rebounds in the season
# 	      drb 	 Average number of defensive rebounds in the season
# 	      acc 	 Shooting accuracy in the season
# 	      a/t 	 Average number of assists vs turnovers in the season
#
# Aspect: orb
#
#
#         From which season should the data be sourced?
#         Please type in the year in which the season ended.
#         For example, if you are interested in season 2021/22, type in:
#             2022
#
# Ending year of season: 2022
#
#
#         From which NBA team(s) should the data be sourced?
#         Please type in for each team either the three-letter abbreviation or
#         the official name. If you are interested in multiple teams,
# ...

# %% [markdown]
# ### Accuracy

# %%
# %run main.py
# Out:
#         What aspect would you like to be visualized?
#         Choose one of the following options:
#         Type in:      Option:
# 	      mar 	 Winning / losing margins for all games in the season
# 	      pts 	 Average points per game in the season
# 	      orb 	 Average number of offensive rebounds in the season
# 	      drb 	 Average number of defensive rebounds in the season
# 	      acc 	 Shooting accuracy in the season
# 	      a/t 	 Average number of assists vs turnovers in the season
#
# Aspect: acc
#
#
#         From which season should the data be sourced?
#         Please type in the year in which the season ended.
#         For example, if you are interested in season 2021/22, type in:
#             2022
#
# Ending year of season: 1992
#
#
#         From which NBA team(s) should the data be sourced?
#         Please type in for each team either the three-letter abbreviation or
#         the official name. If you are interested in multiple teams,
# ...

# %% [markdown]
# ### Assists vs Turnovers

# %%
# %run main.py
# Out:
#         What aspect would you like to be visualized?
#         Choose one of the following options:
#         Type in:      Option:
# 	      mar 	 Winning / losing margins for all games in the season
# 	      pts 	 Average points per game in the season
# 	      orb 	 Average number of offensive rebounds in the season
# 	      drb 	 Average number of defensive rebounds in the season
# 	      acc 	 Shooting accuracy in the season
# 	      a/t 	 Average number of assists vs turnovers in the season
#
# Aspect: a/t
#
#
#         From which season should the data be sourced?
#         Please type in the year in which the season ended.
#         For example, if you are interested in season 2021/22, type in:
#             2022
#
# Ending year of season: 1980
#
#
#         From which NBA team(s) should the data be sourced?
#         Please type in for each team either the three-letter abbreviation or
#         the official name. If you are interested in multiple teams,
# ...

# %% [markdown]
# ## 2 Incorrect inputs

# %%
# %run main.py
# Out:
#         What aspect would you like to be visualized?
#         Choose one of the following options:
#         Type in:      Option:
# 	      mar 	 Winning / losing margins for all games in the season
# 	      pts 	 Average points per game in the season
# 	      orb 	 Average number of offensive rebounds in the season
# 	      drb 	 Average number of defensive rebounds in the season
# 	      acc 	 Shooting accuracy in the season
# 	      a/t 	 Average number of assists vs turnovers in the season
#
# Aspect:
# Please choose one of the options given above.
# Aspect: ca
# Please choose one of the options given above.
# Aspect: acc, pts
# Please choose one of the options given above.
# Aspect: acc
#
#
#         From which season should the data be sourced?
#         Please type in the year in which the season ended.
#         For example, if you are interested in season 2021/22, type in:
#             2022
#
# Ending year of season: 1960
# ...

# %% [markdown]
# ## Correct input, but not recognized due to limitation explained in README.md

# %%
# %run main.py
# Out:
#         What aspect would you like to be visualized?
#         Choose one of the following options:
#         Type in:      Option:
# 	      mar 	 Winning / losing margins for all games in the season
# 	      pts 	 Average points per game in the season
# 	      orb 	 Average number of offensive rebounds in the season
# 	      drb 	 Average number of defensive rebounds in the season
# 	      acc 	 Shooting accuracy in the season
# 	      a/t 	 Average number of assists vs turnovers in the season
#
# Aspect: pts
#
#
#         From which season should the data be sourced?
#         Please type in the year in which the season ended.
#         For example, if you are interested in season 2021/22, type in:
#             2022
#
# Ending year of season: 1947
#
#
#         From which NBA team(s) should the data be sourced?
#         Please type in for each team either the three-letter abbreviation or
#         the official name. If you are interested in multiple teams,
# ...
